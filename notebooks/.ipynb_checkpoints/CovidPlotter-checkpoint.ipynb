# %%
import json
import os
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import io

DAILY_TREND_JSON = 'data/dailyTrend.json'

# %%
print('foo')
# Out:
# foo

# %%
df = pd.read_json(DAILY_TREND_JSON)
df = df.tail(90)

days = list(map(lambda x: datetime.datetime.strptime(x['name'],'%Y-%m-%d'), data))
dows = list(map(lambda x: x.strftime('%A'), days))
sumtokyo = list(map(lambda x: x['Tokyo'], data))
avg7d = list(map(lambda x: x['7dayAvg'], data))

df['datet'] = df['name'].apply(lambda x: datetime.datetime.strptime(x,'%Y-%m-%d'))
df['dow'] = df['datet'].apply(lambda x: x.strftime('%A'))
df['Sun'] = df[df['dow'] == 'Sunday']['Tokyo']
df['Mon'] = df[df['dow'] == 'Monday']['Tokyo']
df['Tue'] = df[df['dow'] == 'Tuesday']['Tokyo']
df['Wed'] = df[df['dow'] == 'Wednesday']['Tokyo']
df['Thu'] = df[df['dow'] == 'Thursday']['Tokyo']
df['Fri'] = df[df['dow'] == 'Friday']['Tokyo']
df['Sat'] = df[df['dow'] == 'Saturday']['Tokyo']
df = df.fillna(method='ffill')
df = df.set_index('name')

# #plotting overlays fun 
# fig,ax1 = plt.subplots(figsize=(14, 8)) 
plt.title('Day of Week Analysis (90 days)')
# plt.xticks(rotation=70)
# ax1.set_ylabel('# New Cases')  # we already handled the x-label with ax1
# ax1.bar(df.index, df['Tokyo'], color='xkcd:silver', label='daily')
# ax1.plot(df.index, df['7dayAvg'], color='xkcd:blue', label='7day avg')
# ax1.plot(df.index, df['Sun'], color='xkcd:blue', label='Sun')
# ax1.plot(df.index, df['Mon'], color='xkcd:green', label='Mon')
# ax1.plot(df.index, df['Tue'], color='xkcd:yellow', label='Tue')
# ax1.plot(df.index, df['Wed'], color='xkcd:orange', label='Wed')
# ax1.plot(df.index, df['Thu'], color='xkcd:red', label='Thu')
# ax1.plot(df.index, df['Fri'], color='xkcd:black', label='Fri')
# ax1.plot(df.index, df['Sat'], color='xkcd:brown', label='Sat')
df.boxplot(column=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])


df = pd.read_json(DAILY_TREND_JSON)
df = df.tail(30)
plt.title('Day of Week Analysis (30 days)')
df.boxplot(column=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])


df = pd.read_json(DAILY_TREND_JSON)
df = df.tail(180)
plt.title('Day of Week Analysis (180 days)')
df.boxplot(column=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])

#ax1.legend(loc='upper left')


# ax1.set_ylabel('# New Cases')  # we already handled the x-label with ax1
# ax1.bar(days[-30:], sumtokyo[-30:], color='xkcd:silver', label='daily')
# ax1.plot(days[-30:], avg7d[-30:], color='xkcd:blue', label='7day avg')
# # ax1.plot(avg30d.tail(30).index, avg30d.tail(30), color='xkcd:red', label='30day avg')
# ax1.legend(loc='upper left')

df.tail(10)
# Out:
#             Tokyo     7dayAvg      datet        dow    Sun    Mon    Tue  \
# name
# 2020-11-08    189  201.714286 2020-11-08     Sunday  189.0   87.0  209.0
# 2020-11-09    157  211.714286 2020-11-09     Monday  189.0  157.0  209.0
# 2020-11-10    293  223.714286 2020-11-10    Tuesday  189.0  157.0  293.0
# 2020-11-11    317  251.571429 2020-11-11  Wednesday  189.0  157.0  293.0
# 2020-11-12    393  269.285714 2020-11-12   Thursday  189.0  157.0  293.0
# 2020-11-13    374  288.142857 2020-11-13     Friday  189.0  157.0  293.0
# 2020-11-14    352  296.428571 2020-11-14   Saturday  189.0  157.0  293.0
# 2020-11-15    255  305.857143 2020-11-15     Sunday  255.0  157.0  293.0
# 2020-11-16    180  309.142857 2020-11-16     Monday  255.0  180.0  293.0
# 2020-11-17    298  309.857143 2020-11-17    Tuesday  255.0  180.0  298.0
#
#               Wed    Thu    Fri    Sat
# name
# 2020-11-08  122.0  269.0  242.0  294.0
# 2020-11-09  122.0  269.0  242.0  294.0
# ...
